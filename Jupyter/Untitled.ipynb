# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import csv
import pdb
import os
import matplotlib.pyplot as plt
import timeit
from joblib import dump, load

# %%
def load_data(directory, target_var):
    full_data = []
    if directory[-1] != '/':
        directory = directory + '/'
    for root,dir,files in os.walk(directory):
        for file in files:
            if file.endswith(".csv"):
                filepath = directory + file
                print('Loading: ', file)
                csv_data = np.genfromtxt(filepath, delimiter=',')
                full_data.append(csv_data)
    features = np.vstack(full_data)
    ground_truth = features[:,target_var]
    features = np.delete(features, target_var, axis=1)
    
    return features, ground_truth, full_data

# %%
truth_index = 2
start = timeit.default_timer()
features, ground_truth, _ = load_data('/mnt/d/git/heat_chamber_code/jupyter/variable size and temp/', truth_index)
# Out:
# Loading:  0.50AlTemps1510100.csv
# Loading:  0.50AlTemps151040.csv
# Loading:  0.50AlTemps151045.csv
# Loading:  0.50AlTemps151050.csv
# Loading:  0.50AlTemps151055.csv
# Loading:  0.50AlTemps151060.csv
# Loading:  0.50AlTemps151080.csv
# Loading:  0.50AlTemps151085.csv
# Loading:  0.50AlTemps151090.csv
# Loading:  0.50AlTemps151095.csv
# Loading:  0.50AlTemps1515100.csv
# Loading:  0.50AlTemps151540.csv
# Loading:  0.50AlTemps151545.csv
# Loading:  0.50AlTemps151550.csv
# Loading:  0.50AlTemps151555.csv
# Loading:  0.50AlTemps151560.csv
# Loading:  0.50AlTemps151580.csv
# Loading:  0.50AlTemps151585.csv
# Loading:  0.50AlTemps151590.csv
# Loading:  0.50AlTemps151595.csv
# Loading:  0.50AlTemps1520100.csv
# Loading:  0.50AlTemps152040.csv
# Loading:  0.50AlTemps152045.csv
# Loading:  0.50AlTemps152050.csv
# Loading:  0.50AlTemps152055.csv
# Loading:  0.50AlTemps152060.csv
# Loading:  0.50AlTemps152080.csv
# Loading:  0.50AlTemps152085.csv
# Loading:  0.50AlTemps152090.csv
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(features, ground_truth, test_size=0.33, random_state=42)
forest = RandomForestRegressor(random_state=42)
forest.fit(X_train, y_train)
dump(forest, 'random_forest_model_test2.joblib')
score = forest.score(X_test, y_test)
print("Score: ", score)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Score:  0.9950746743966862
